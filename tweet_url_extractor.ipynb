# %%
import urlexpander
import tweepy
import requests, json
import re
import configure  as cf
import helper.Utils as Utils


def expand_url_using_requests(url):
    try:
        session = requests.Session()  # so connections are recycled
        resp = session.head(url, allow_redirects=True,timeout=10)
        return resp.url
    except:
        return ""

def expand_url(shortened_url):
    # shortened_url = shortened_url.replace(' ','')
    CLIENT_ERROR = "__CLIENT_ERROR__"
    CONNECTIONPOOL_ERROR = "__CONNECTIONPOOL_ERROR__"
    expanded_url = ""
    try:
        expanded_url = urlexpander.expand(shortened_url) # expand url using urlexpander library

        if CLIENT_ERROR in expanded_url:
            expanded_url = expand_url_using_requests(shortened_url)     # expand url using custom function. Another way if the first didn't work
            if CLIENT_ERROR in expanded_url:
                print("Client error while expanding url: ", shortened_url)
                expanded_url = ""

        if CONNECTIONPOOL_ERROR in expanded_url:
            expanded_url = expand_url_using_requests(shortened_url)     # expand url using custom function. Another way if the first didn't work
            if CONNECTIONPOOL_ERROR in expanded_url:
                print("CONNECTION POOL error while expanding url: ", shortened_url)
                expanded_url = ""

    except:
        print("Cannot expand this url ", shortened_url)
        expanded_url = ""
    return expanded_url

def get_webpage_title(expanded_url):
    
    PAGE_404 = "page 404"
    PAGE_NOT_FOUND = "Page not found"
    title = ""
    try:
        meta = urlexpander.html_utils.get_webpage_meta(expanded_url)
        title = meta["title"]

        if PAGE_NOT_FOUND.lower() in title.lower() or PAGE_404 in title:
            print("Page not found for this url: ", expanded_url)
            title = ""
    except:
        title = ""
    return title


def get_api():
    consumer_key ="XXXXXXXXX"
    consumer_secret = "XXXXXXXXX"
    access_token = "XXXXXXXXX-XXXXXXXXX"
    access_token_secret = "XXXXXXXXX"

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    # perform authentication and get api object
    api = tweepy.API(auth)
    return api

def get_username_out_of_handle(api, user_handle):
    user_name = ""
    DONALD_TRUMP_HANDLE = "realdonaldtrump"
    DONALD_TRUMP_USERNAME = "Donald Trump"
    try:
        # clean the handle
        user_handle = user_handle.lower()
        user_handle = user_handle.replace('@','')
        user_handle = user_handle.replace(' ','')

        if DONALD_TRUMP_HANDLE == user_handle:
            return DONALD_TRUMP_USERNAME
            
        user = api.get_user(user_handle)
        user_id = user.id
        user_name = user.name
    except:
        user_name = ""
        print("Error in getting user name for this handle : ", user_handle)

    return user_name

# %%
def get_image_best_guest_from_url(image_url):

    try:
        server_url = "http://localhost:5000/search"
        data = {"image_url": image_url}
        headers = {'Content-type': 'application/json'}
        response = requests.post(server_url, headers=headers, data=json.dumps(data))
        json_response = response.json()
        best_guess = json_response['best_guess']
        if best_guess == "language" or best_guess == "event":
        # if the best guess is only one of these words, then no need to add them to the query
            best_guess = "" 
    except:
        print("Error: cannot get the best guess for this image url: ", image_url)
        best_guess = ""

    return best_guess

def get_image_best_guess_from_tweet_id(api, tweet_id):
    try:
        tweet = api.get_status(tweet_id, tweet_mode="extended")
    except:
        print("Error: No data available for specified ID ", tweet_id)
        return ""
        
    image_best_guess= ""

    if 'media' in tweet.entities:
        for media in tweet.extended_entities['media']:
            try:
                image_url = media['media_url']
                image_best_guess = image_best_guess + get_image_best_guest_from_url(image_url) + " "
            except:
                print("Error: Unable to extract best guess for this tweet : ", tweet_id)

    return image_best_guess

# %%
def reformat_urls(tweet):
    ''' Separate consecutive URLs with spaces, and add https prior to pic.twitter'''
    tweet = tweet.replace("https", " https") 
    tweet = tweet.replace("http", " http") 
    tweet = tweet.replace("pic.twitter", " https://pic.twitter") 
    return tweet

def remove_handle_from_second_part(tweet):
    try:
        if '—' in tweet:
            second_part = tweet.split('—')[1]
            new_second_part = re.sub(r"@[\w]*", " ", second_part)  # remove handles
            tweet = tweet.replace(second_part, new_second_part) 
    except:
        print("Cannot remove handle from second part for this tweet: ", tweet)
    return tweet


def get_tweet_id(tweet_url):
    try:
        # 1. get everything after 'status/' 2. Remove everything after '?' 3. Get the id before the first '/'
        tweet_id = tweet_url.split('status/')[-1].split('?')[0].split('/')[0] 
    except:
        print("Error: cannot get the id out of this url: ", tweet_url)
        tweet_id = ""
    return tweet_id

def get_information_out_of_URLs(tweet):

    api = get_api()
    TWITTER_URL = "https://twitter.com"
    tweet_image_shortened_urls = []
    tweet_image_best_guesses = []

    # 1. Format URLs in a readable way and remove handle from second part. Username for the handle in the second part is already exist
    tweet = reformat_urls(tweet)
    tweet = remove_handle_from_second_part(tweet)

    # 2. Replace handles with their names 
    handle_pattern = re.compile(r"@[\w]*")
    iterator = handle_pattern.finditer(tweet)
    for match in iterator:
        user_handle = match.group() # group: Return the string matched by the RE
        user_name = get_username_out_of_handle(api, user_handle)
        tweet = tweet.replace(user_handle, user_name)

    # 3. Replace twitter picture with their best guess, and webpages urls with their title
    url_pattern = re.compile(r"http\S+") # find every url 
    iterator = url_pattern.finditer(tweet)
    for match in iterator:
        shortened_url = match.group() # group: Return the string matched by the RE
        expanded_url = expand_url(shortened_url)

        if TWITTER_URL in expanded_url: # then it is a tweet URL, we need to get its id
            print("Getting image info for this url : ", expanded_url)
            tweet_id = get_tweet_id(expanded_url)
            # get the image url and do reverse image search
            image_best_guess = get_image_best_guess_from_tweet_id(api, tweet_id)

            tweet_image_shortened_urls.append(shortened_url)
            tweet_image_best_guesses.append(image_best_guess)
            
            if image_best_guess != "":
                image_best_guess = ", "+ image_best_guess + ","

            tweet = tweet.replace(shortened_url, image_best_guess)

        else:  # it is an URL to a webpage. Fetch the webpage title and replace it with its url
            
            webpage_title = get_webpage_title(expanded_url)
            webpage_title = re.sub(r'\W*$', '', webpage_title) # remove punctuation from the tail
            tweet_first_part = tweet.split("—")[0]
            tweeet_first_part_without_url = tweet_first_part.replace(shortened_url, "").strip()
            
            # # if tweet first part is in webpage title,
            # if tweeet_first_part_without_url in webpage_title:
            #     tweet = tweet.replace(tweet_first_part, webpage_title)
            # else:
            # if the webpage title is part of the tweet, then no need to add it,
            if webpage_title in tweet:
                webpage_title = ""
            tweet = tweet.replace(shortened_url, webpage_title)
    
    return tweet, tweet_image_shortened_urls, tweet_image_best_guesses


def clean_queries_from_urls(query_path, output_save_path):
    print("---------------------------------------- Extracting information from tweet URLs using the query path: ", query_path)
    print(" ---------------------------------------------------------------------------------------------------------")
    df_query = Utils.read_file(query_path)
    cleaned_tweets = []
    all_tweet_image_shortened_urls = []
    all_tweet_image_best_guesses = []
    all_tweet_image_titles = []
    num  = 0
    for i, row in df_query.iterrows():
        print("Processing tweet number ", num , " with id ", row[TWEET_ID_COLUMN])
        tweet = row[TWEET_TEXT_COLUMN]
        tweet, tweet_image_shortened_urls, tweet_image_best_guesses = get_information_out_of_URLs(tweet)
        cleaned_tweets.append(tweet)
        all_tweet_image_shortened_urls.append(tweet_image_shortened_urls)
        all_tweet_image_best_guesses.append(tweet_image_best_guesses)
        num = num + 1

    df_query["cleaned"] = cleaned_tweets
    df_query["shortened_tweet_urls"] = all_tweet_image_shortened_urls
    df_query["best_guesses"] = all_tweet_image_best_guesses
    df_query.to_excel(output_save_path, index=False)

# %%
# define some constants.
TWEET_ID_COLUMN = cf.TWEET_ID
TWEET_TEXT_COLUMN = cf.TWEET_TEXT

# %% [markdown]
# Just to check if the MRIZA is working

# %%
tweet_id = "1214905880732459009" # us military draft email 
api = get_api()
print(get_image_best_guess_from_tweet_id(api, tweet_id))
# Out:
# us military draft email

# %% [markdown]
# ### Arabic, CLEF 2022: Cleaning train, dev, and test sets from URLs and replace URLs with useful information

# %%
train_query_path = cf.AR_2022_TRAIN_QUERY
dev_query_path = cf.AR_2022_DEV_QUERY
test_query_path = cf.AR_2022_TEST_QUERY

# df_query = clean_queries_from_urls(train_query_path, output_save_path=gb.AR_2022_CLEANED_TRAIN_QURRIES)
# df_query = clean_queries_from_urls(dev_query_path, output_save_path=gb.AR_2022_CLEANED_DEV_QURRIES)
df_query = clean_queries_from_urls(test_query_path, output_save_path=cf.AR_2022_CLEANED_TEST_QURRIES)
# Out:
# ---------------------------------------- Extracting information from tweet URLs using the query path:  ./data/CLEF_2022/Arabic/CT2022-Task2A-AR-Test_Queries.tsv
#  ---------------------------------------------------------------------------------------------------------
# Processing tweet number  0  with id  tweet-ar-22-test-0
# Processing tweet number  1  with id  tweet-ar-22-test-1
# Processing tweet number  2  with id  tweet-ar-22-test-2
# Processing tweet number  3  with id  tweet-ar-22-test-3
# Processing tweet number  4  with id  tweet-ar-22-test-4
# Processing tweet number  5  with id  tweet-ar-22-test-5
# Processing tweet number  6  with id  tweet-ar-22-test-6
# Processing tweet number  7  with id  tweet-ar-22-test-7
# Processing tweet number  8  with id  tweet-ar-22-test-8
# Processing tweet number  9  with id  tweet-ar-22-test-9
# Processing tweet number  10  with id  tweet-ar-22-test-10
# Processing tweet number  11  with id  tweet-ar-22-test-11
# Processing tweet number  12  with id  tweet-ar-22-test-12
# Processing tweet number  13  with id  tweet-ar-22-test-13
# Processing tweet number  14  with id  tweet-ar-22-test-14
# Processing tweet number  15  with id  tweet-ar-22-test-15
# Processing tweet number  16  with id  tweet-ar-22-test-16
# Processing tweet number  17  with id  tweet-ar-22-test-17
# Processing tweet number  18  with id  tweet-ar-22-test-18
# Processing tweet number  19  with id  tweet-ar-22-test-19
# Processing tweet number  20  with id  tweet-ar-22-test-20
# Getting image info for this url :  https://twitter.com/NourNajjarSy1/status/1429138378574942210/photo/1
# Processing tweet number  21  with id  tweet-ar-22-test-21
# Processing tweet number  22  with id  tweet-ar-22-test-22
# Getting image info for this url :  https://twitter.com/alekhbariyatv/status/1423155556357869572/video/1
# Processing tweet number  23  with id  tweet-ar-22-test-23
# Processing tweet number  24  with id  tweet-ar-22-test-24
# Processing tweet number  25  with id  tweet-ar-22-test-25
# Getting image info for this url :  https://twitter.com/sadeqatyia/status/1378405304744996865/photo/1
# Processing tweet number  26  with id  tweet-ar-22-test-26
# Processing tweet number  27  with id  tweet-ar-22-test-27
# Processing tweet number  28  with id  tweet-ar-22-test-28
# Processing tweet number  29  with id  tweet-ar-22-test-29
# Processing tweet number  30  with id  tweet-ar-22-test-30
# Processing tweet number  31  with id  tweet-ar-22-test-31
# Processing tweet number  32  with id  tweet-ar-22-test-32
# Processing tweet number  33  with id  tweet-ar-22-test-33
# Processing tweet number  34  with id  tweet-ar-22-test-34
# Processing tweet number  35  with id  tweet-ar-22-test-35
# Processing tweet number  36  with id  tweet-ar-22-test-36
# Processing tweet number  37  with id  tweet-ar-22-test-37
# Processing tweet number  38  with id  tweet-ar-22-test-38
# Processing tweet number  39  with id  tweet-ar-22-test-39
# Processing tweet number  40  with id  tweet-ar-22-test-40
# Processing tweet number  41  with id  tweet-ar-22-test-41
# Processing tweet number  42  with id  tweet-ar-22-test-42
# Processing tweet number  43  with id  tweet-ar-22-test-43
# Processing tweet number  44  with id  tweet-ar-22-test-44
# Processing tweet number  45  with id  tweet-ar-22-test-45
# Processing tweet number  46  with id  tweet-ar-22-test-46
# Processing tweet number  47  with id  tweet-ar-22-test-47
# Processing tweet number  48  with id  tweet-ar-22-test-48
# Processing tweet number  49  with id  tweet-ar-22-test-49

# %% [markdown]
# ## -----------------------------------------------------------

# %% [markdown]
# ### English, CLEF 2022: Cleaning train, dev, and test sets from URLs and replace URLs with useful information

# %%
train_query_path = cf.EN_2022_TRAIN_QUERY
dev_query_path = cf.EN_2022_DEV_QUERY
test_query_path = cf.EN_2022_TEST_QUERY

# df_query = clean_queries_from_urls(train_query_path, output_save_path=gb.EN_2022_CLEANED_TRAIN_QURRIES)
# df_query = clean_queries_from_urls(dev_query_path, output_save_path=gb.EN_2022_CLEANED_DEV_QURRIES)
df_query = clean_queries_from_urls(test_query_path, output_save_path=cf.EN_2022_CLEANED_TEST_QURRIES)
# Out:
# ---------------------------------------- Extracting information from tweet URLs using the query path:  ./data/CLEF_2022/English/CT2022-Task2A-EN-Test_Queries.tsv
#  ---------------------------------------------------------------------------------------------------------
# Processing tweet number  0  with id  tweet-sno-1198
# Getting image info for this url :  https://twitter.com/timkmak/status/1500822536346603531/photo/1
# Processing tweet number  1  with id  tweet-sno-1199
# Processing tweet number  2  with id  tweet-sno-1200
# Getting image info for this url :  https://twitter.com/FedorovMykhailo/status/1498392515262746630/photo/1
# Processing tweet number  3  with id  tweet-sno-1201
# Getting image info for this url :  https://twitter.com/FedorovMykhailo/status/1501648932824301570/photo/1
# Processing tweet number  4  with id  tweet-sno-1202
# Processing tweet number  5  with id  tweet-sno-1203
# Getting image info for this url :  https://twitter.com/travisakers/status/1499041366696992772/video/1
# Processing tweet number  6  with id  tweet-sno-1204
# Getting image info for this url :  https://twitter.com/Lily0727K/status/1499998963193499652
# Processing tweet number  7  with id  tweet-sno-1205
# Getting image info for this url :  https://twitter.com/MrPatrickMulder/status/1498253119658016768/photo/1
# Processing tweet number  8  with id  tweet-sno-1206
# Processing tweet number  9  with id  tweet-sno-1207
# Getting image info for this url :  https://twitter.com/BowTiedRanger/status/1494508996811706376/photo/1
# Processing tweet number  10  with id  tweet-sno-1208
# Getting image info for this url :  https://twitter.com/TIME/status/1497010566581346307/photo/1
# Processing tweet number  11  with id  tweet-sno-1209
# Processing tweet number  12  with id  tweet-sno-1210
# Processing tweet number  13  with id  tweet-sno-1211
# Getting image info for this url :  https://twitter.com/nickclegg/status/1498014379262025737
# Processing tweet number  14  with id  tweet-sno-1212
# Getting image info for this url :  https://twitter.com/jamiefullerton1/status/1496927144743739392/photo/1
# Processing tweet number  15  with id  tweet-sno-1213
# Getting image info for this url :  https://twitter.com/RobertMackey/status/1496969222777278466/video/1
# Processing tweet number  16  with id  tweet-sno-1214
# Getting image info for this url :  https://twitter.com/ragipsoylu/status/1496555399499157516/video/1
# Processing tweet number  17  with id  tweet-sno-1215
# Getting image info for this url :  https://twitter.com/ItsOlegi21/status/1497164782952239104/video/1
# Processing tweet number  18  with id  tweet-sno-1216
# Getting image info for this url :  https://twitter.com/jmiklovas/status/1496908640569237504/video/1
# Processing tweet number  19  with id  tweet-sno-1217
# Getting image info for this url :  https://twitter.com/NguyenK37230640/status/1496863614577549314/video/1
# Error: No data available for specified ID  1496863614577549314
# Processing tweet number  20  with id  tweet-sno-1218
# Getting image info for this url :  https://twitter.com/WorldNewsWWIII/status/1496742463054172162/video/1
# Error: No data available for specified ID  1496742463054172162
# Processing tweet number  21  with id  tweet-sno-1219
# Getting image info for this url :  https://twitter.com/atrupar/status/1496696954063134720/video/1
# Processing tweet number  22  with id  tweet-sno-1220
# Getting image info for this url :  https://twitter.com/Zappos/status/1493304294539505678/video/1
# Processing tweet number  23  with id  tweet-sno-1221
# Getting image info for this url :  https://twitter.com/RapUp/status/1234669103329099778/photo/1
# Processing tweet number  24  with id  tweet-sno-1222
# Getting image info for this url :  https://twitter.com/ariehkovler/status/1494332545218928642/photo/1
# Processing tweet number  25  with id  tweet-sno-1223
# Getting image info for this url :  https://twitter.com/TheFirstonTV/status/1492245199317311492/video/1
# Processing tweet number  26  with id  tweet-sno-1224
# Getting image info for this url :  https://twitter.com/MuhammadLila/status/1069609790802784257/video/1
# Processing tweet number  27  with id  tweet-sno-1225
# Getting image info for this url :  https://twitter.com/gifdsports/status/1493032941575974914/photo/1
# Processing tweet number  28  with id  tweet-sno-1226
# Getting image info for this url :  https://twitter.com/FY3TV/status/1493035119606648834/video/1
# Processing tweet number  29  with id  tweet-sno-1227
# Getting image info for this url :  https://twitter.com/AccountableGOP/status/1491525010997096449/video/1
# Processing tweet number  30  with id  tweet-sno-1228
# Getting image info for this url :  https://twitter.com/townhallcom/status/1489310513909702657/video/1
# Processing tweet number  31  with id  tweet-sno-1229
# Getting image info for this url :  https://twitter.com/leahmcelrath/status/1489341768722268161/photo/1
# Processing tweet number  32  with id  tweet-sno-1230
# Getting image info for this url :  https://twitter.com/edbonillab/status/1397746847620415492
# Processing tweet number  33  with id  tweet-sno-1231
# Getting image info for this url :  https://twitter.com/HeatherWhaley/status/1352638507399962633/video/1
# Processing tweet number  34  with id  tweet-sno-1232
# Processing tweet number  35  with id  tweet-sno-1233
# Getting image info for this url :  https://twitter.com/kevinmgill/status/1054422462312570880/video/1
# Processing tweet number  36  with id  tweet-sno-1234
# Getting image info for this url :  https://twitter.com/misscovurgurll/status/1485830451818221572/video/1
# Error: No data available for specified ID  1485830451818221572
# Processing tweet number  37  with id  tweet-sno-1235
# Processing tweet number  38  with id  tweet-sno-1236
# Getting image info for this url :  https://twitter.com/Acyn/status/1485739301685972992/video/1
# Processing tweet number  39  with id  tweet-sno-1237
# Getting image info for this url :  https://twitter.com/profshanecrotty/status/1455263624730087424/photo/1
# Processing tweet number  40  with id  tweet-sno-1238
# Getting image info for this url :  https://twitter.com/hotkeno/status/1128419678919860224/photo/1
# Processing tweet number  41  with id  tweet-sno-1239
# Getting image info for this url :  https://twitter.com/SInow/status/1483273124640702472/photo/1
# Processing tweet number  42  with id  tweet-sno-1240
# Getting image info for this url :  https://twitter.com/sportsvids1/status/1483274834922676234/video/1
# Processing tweet number  43  with id  tweet-sno-1241
# Processing tweet number  44  with id  tweet-sno-1242
# Processing tweet number  45  with id  tweet-sno-1243
# Getting image info for this url :  https://twitter.com/realchrisrufo/status/1369779150001565697/photo/1
# Processing tweet number  46  with id  tweet-sno-1244
# Processing tweet number  47  with id  tweet-sno-1245
# Processing tweet number  48  with id  tweet-sno-1246
# Getting image info for this url :  https://twitter.com/RoshanCricket/status/1294198786609348608/video/1
# Processing tweet number  49  with id  tweet-sno-1247
# Getting image info for this url :  https://twitter.com/kerpen/status/1479652360779669504/video/1
# Processing tweet number  50  with id  tweet-sno-1248
# Getting image info for this url :  https://twitter.com/brezelradar/status/1478960909531942913/video/1
# Processing tweet number  51  with id  tweet-sno-1249
# Getting image info for this url :  https://twitter.com/songpinganq/status/1477506236925247493/video/1
# Processing tweet number  52  with id  tweet-sno-1250
# Getting image info for this url :  https://twitter.com/_BarringtonII/status/1480363778818641931/video/1
# Processing tweet number  53  with id  tweet-sno-1251
# Getting image info for this url :  https://twitter.com/BeschlossDC/status/990672662686064640/photo/1
# Processing tweet number  54  with id  tweet-sno-1252
# Getting image info for this url :  https://twitter.com/zznzqo/status/1480302328263569416/video/1
# Error: No data available for specified ID  1480302328263569416
# Processing tweet number  55  with id  tweet-sno-1253
# Getting image info for this url :  https://twitter.com/MrMichaelSpicer/status/1477937485799899140/video/1
# Processing tweet number  56  with id  tweet-sno-1254
# Getting image info for this url :  https://twitter.com/patriottakes/status/1479116054957674499/photo/1
# Processing tweet number  57  with id  tweet-sno-1255
# Processing tweet number  58  with id  tweet-sno-1256
# Getting image info for this url :  https://twitter.com/DJcalligraphy/status/1419074788618694657/photo/1
# Error: No data available for specified ID  1419074788618694657
# Processing tweet number  59  with id  tweet-sno-1257
# Getting image info for this url :  https://twitter.com/Out_of_Spec/status/1478490873121837057/video/1
# Processing tweet number  60  with id  tweet-sno-1258
# Processing tweet number  61  with id  tweet-sno-1259
# Getting image info for this url :  https://twitter.com/litcapital/status/1475508403732721664/photo/1
# Processing tweet number  62  with id  tweet-sno-1260
# Getting image info for this url :  https://twitter.com/insurancecrime/status/1474409689723113475/photo/1
# Processing tweet number  63  with id  tweet-sno-1261
# Getting image info for this url :  https://twitter.com/Kukicat7/status/1473743177806974977/video/1
# Error: No data available for specified ID  1473743177806974977
# Processing tweet number  64  with id  tweet-sno-1262
# Getting image info for this url :  https://twitter.com/statsjamie/status/1473583067784744962/video/1
# Processing tweet number  65  with id  tweet-sno-1263
# Getting image info for this url :  https://twitter.com/RonFilipkowski/status/1473039073535213570/video/1
# Processing tweet number  66  with id  tweet-sno-1264
# Processing tweet number  67  with id  tweet-sno-1265
# Getting image info for this url :  https://twitter.com/XmasMovieFacts/status/1206282658491371520/photo/1
# Processing tweet number  68  with id  tweet-sno-1266
# Processing tweet number  69  with id  tweet-sno-1267
# Getting image info for this url :  https://twitter.com/XmasMovieFacts/status/1076301766436835328/photo/1
# Processing tweet number  70  with id  tweet-sno-1268
# Getting image info for this url :  https://twitter.com/mattbucknelltx/status/1471558593086427145/video/1
# Processing tweet number  71  with id  tweet-sno-1269
# Processing tweet number  72  with id  tweet-sno-1270
# Getting image info for this url :  https://twitter.com/BreitbartNews/status/1469321946114445312/video/1
# Processing tweet number  73  with id  tweet-sno-1271
# Processing tweet number  74  with id  tweet-sno-1272
# Getting image info for this url :  https://twitter.com/amanbatheja/status/403281830629367808/photo/1
# Processing tweet number  75  with id  tweet-sno-1273
# Getting image info for this url :  https://twitter.com/AnonCitizenUK/status/1467525765474443264/video/1
# Error: No data available for specified ID  1467525765474443264
# Processing tweet number  76  with id  tweet-sno-1274
# Getting image info for this url :  https://twitter.com/Shayan86/status/1467876873023676416/photo/1
# Processing tweet number  77  with id  tweet-sno-1275
# Getting image info for this url :  https://twitter.com/TrackerTrial/status/1462795006889103368/photo/1
# Error: No data available for specified ID  1462795006889103368
# Processing tweet number  78  with id  tweet-sno-1276
# Processing tweet number  79  with id  tweet-sno-1277
# Getting image info for this url :  https://twitter.com/danielmarven/status/1464894181210476549/photo/1
# Processing tweet number  80  with id  tweet-sno-1278
# Processing tweet number  81  with id  tweet-sno-1279
# Getting image info for this url :  https://twitter.com/CerebrumScops/status/1465741090879901704/photo/1
# Error: No data available for specified ID  1465741090879901704
# Processing tweet number  82  with id  tweet-sno-1280
# Processing tweet number  83  with id  tweet-sno-1281
# Processing tweet number  84  with id  tweet-sno-1282
# Processing tweet number  85  with id  tweet-sno-1283
# Getting image info for this url :  https://twitter.com/FDArecalls/status/1464298402636865544/photo/1
# Processing tweet number  86  with id  tweet-sno-1284
# Getting image info for this url :  https://twitter.com/TrumpJew2/status/1463231106715721736/video/1
# Error: No data available for specified ID  1463231106715721736
# Processing tweet number  87  with id  tweet-sno-1285
# Getting image info for this url :  https://twitter.com/FDArecalls/status/1462814027478929414/photo/1
# Processing tweet number  88  with id  tweet-sno-1286
# Getting image info for this url :  https://twitter.com/latestinspace/status/1432827827691401224/photo/1
# Processing tweet number  89  with id  tweet-sno-1287
# Getting image info for this url :  https://twitter.com/HonestLeYo/status/1461001549870686208/photo/1
# Processing tweet number  90  with id  tweet-sno-1288
# Getting image info for this url :  https://twitter.com/WebMD/status/1459868730989629441/photo/1
# Processing tweet number  91  with id  tweet-sno-1289
# Getting image info for this url :  https://twitter.com/estressecurado/status/1458235069705990149
# Processing tweet number  92  with id  tweet-sno-1290
# Getting image info for this url :  https://twitter.com/ArifurFC/status/1457363447541387269/video/1
# Processing tweet number  93  with id  tweet-sno-1291
# Getting image info for this url :  https://twitter.com/Edi05215930/status/1458248231410978817/video/1
# Error: No data available for specified ID  1458248231410978817
# Processing tweet number  94  with id  tweet-sno-1292
# Getting image info for this url :  https://twitter.com/mysk_co/status/1454016614471553024/video/1
# Processing tweet number  95  with id  tweet-sno-1293
# Getting image info for this url :  https://twitter.com/johncardillo/status/1458040032414081026/photo/1
# Processing tweet number  96  with id  tweet-sno-1294
# Getting image info for this url :  https://twitter.com/LWPhototherapy/status/1457376249031000067/photo/1
# Error: No data available for specified ID  1457376249031000067
# Processing tweet number  97  with id  tweet-sno-1295
# Getting image info for this url :  https://twitter.com/NASAhistory/status/1456387292864581636/photo/1
# Processing tweet number  98  with id  tweet-sno-1296
# Processing tweet number  99  with id  tweet-sno-1297
# Processing tweet number  100  with id  tweet-sno-1298
# Getting image info for this url :  https://twitter.com/RepNancyMace/status/1452036537139466254/photo/1
# Processing tweet number  101  with id  tweet-sno-1299
# Getting image info for this url :  https://twitter.com/peta/status/1453760167363891203/photo/1
# Processing tweet number  102  with id  tweet-sno-1300
# Processing tweet number  103  with id  tweet-sno-1301
# Processing tweet number  104  with id  tweet-sno-1302
# Getting image info for this url :  https://twitter.com/CEOAdam/status/1448349092246138885/photo/1
# Processing tweet number  105  with id  tweet-sno-1303
# Getting image info for this url :  https://twitter.com/GOPoversight/status/1450934193177903105/photo/1
# Processing tweet number  106  with id  tweet-sno-1304
# Processing tweet number  107  with id  tweet-sno-1305
# Getting image info for this url :  https://twitter.com/MikeKBerg/status/1447957307179118592/video/1
# Processing tweet number  108  with id  tweet-sno-1306
# Getting image info for this url :  https://twitter.com/sortabad/status/1093214759502131200
# Processing tweet number  109  with id  tweet-sno-1307
# Getting image info for this url :  https://twitter.com/barstoolsports/status/1138444196044509185/video/1
# Processing tweet number  110  with id  tweet-sno-1308
# Processing tweet number  111  with id  tweet-sno-1309
# Getting image info for this url :  https://twitter.com/AsteroidWatch/status/1443935243006787622/video/1
# Processing tweet number  112  with id  tweet-sno-1310
# Getting image info for this url :  https://twitter.com/AsteroidWatch/status/1436344527191695377/video/1
# Processing tweet number  113  with id  tweet-sno-1311
# Processing tweet number  114  with id  tweet-sno-1312
# Getting image info for this url :  https://twitter.com/people/status/1442940191258255361
# Processing tweet number  115  with id  tweet-sno-1313
# Processing tweet number  116  with id  tweet-sno-1314
# Getting image info for this url :  https://twitter.com/voronincup/status/1443012598329397250/photo/1
# Processing tweet number  117  with id  tweet-sno-1315
# Processing tweet number  118  with id  tweet-sno-1316
# Getting image info for this url :  https://twitter.com/RoyKallivayalil/status/1442014911572299780/video/1
# Processing tweet number  119  with id  tweet-sno-1317
# Processing tweet number  120  with id  tweet-sno-1318
# Getting image info for this url :  https://twitter.com/weird_sci/status/1440511216414171143/photo/1
# Processing tweet number  121  with id  tweet-sno-1319
# Getting image info for this url :  https://twitter.com/LeedsTrinity/status/1064503894854778881/photo/1
# Processing tweet number  122  with id  tweet-sno-1320
# Getting image info for this url :  https://twitter.com/UniShefArch/status/1437746906738929667/photo/1
# Processing tweet number  123  with id  tweet-sno-1321
# Getting image info for this url :  https://twitter.com/RKOTOfficial/status/1438507159898054657/video/1
# Error: No data available for specified ID  1438507159898054657
# Processing tweet number  124  with id  tweet-sno-1322
# Getting image info for this url :  https://twitter.com/MycahABC13/status/1437545252689227778/video/1
# Processing tweet number  125  with id  tweet-sno-1323
# Getting image info for this url :  https://twitter.com/yunhospov/status/1437529048666738688/photo/1
# Processing tweet number  126  with id  tweet-sno-1324
# Processing tweet number  127  with id  tweet-sno-1325
# Getting image info for this url :  https://twitter.com/DaveLeeFT/status/1436826915478786050/video/1
# Processing tweet number  128  with id  tweet-sno-1326
# Getting image info for this url :  https://twitter.com/LionelRichie/status/1433097480875298824/photo/1
# Processing tweet number  129  with id  tweet-sno-1327
# Processing tweet number  130  with id  tweet-sno-1328
# Processing tweet number  131  with id  tweet-sno-1329
# Processing tweet number  132  with id  tweet-sno-1330
# Processing tweet number  133  with id  tweet-sno-1331
# Processing tweet number  134  with id  tweet-sno-1332
# Getting image info for this url :  https://twitter.com/NYGovCuomo/status/1429989369201532934/photo/1
# Processing tweet number  135  with id  tweet-sno-1333
# Getting image info for this url :  https://twitter.com/ZackFinkNews/status/1429794750702436354/photo/1
# Processing tweet number  136  with id  tweet-sno-1334
# Processing tweet number  137  with id  tweet-sno-1335
# Getting image info for this url :  https://twitter.com/Natsecjeff/status/1432347902026911746/video/1
# Processing tweet number  138  with id  tweet-sno-1336
# Getting image info for this url :  https://twitter.com/oryxspioenkop/status/1432698153279574028/photo/1
# Processing tweet number  139  with id  tweet-sno-1337
# Getting image info for this url :  https://twitter.com/TheBionicAnkle/status/1432074692228272132/video/1
# Processing tweet number  140  with id  tweet-sno-1338
# Getting image info for this url :  https://twitter.com/TPostMillennial/status/1431724854047395847/video/1
# Processing tweet number  141  with id  tweet-sno-1339
# Getting image info for this url :  https://twitter.com/KianSharifi/status/1431902295671939077/photo/1
# Processing tweet number  142  with id  tweet-sno-1340
# Getting image info for this url :  https://twitter.com/KianSharifi/status/1431901240187834369/video/1
# Processing tweet number  143  with id  tweet-sno-1341
# Processing tweet number  144  with id  tweet-sno-1342
# Processing tweet number  145  with id  tweet-sno-1343
# Processing tweet number  146  with id  tweet-sno-1344
# Getting image info for this url :  https://twitter.com/oriana0214/status/1428445114762997765
# Processing tweet number  147  with id  tweet-sno-1345
# Processing tweet number  148  with id  tweet-sno-1346
# Getting image info for this url :  https://twitter.com/SecPompeo/status/1304766751251595264/photo/1
# Processing tweet number  149  with id  tweet-sno-1347
# Getting image info for this url :  https://twitter.com/slulay2/status/1424732941977112580/photo/1
# Processing tweet number  150  with id  tweet-sno-1348
# Getting image info for this url :  https://twitter.com/TrumpJew2/status/1423668833697546250/video/1
# Error: No data available for specified ID  1423668833697546250
# Processing tweet number  151  with id  tweet-sno-1349
# Getting image info for this url :  https://twitter.com/clockoutwars/status/1423600290180341765/photo/1
# Processing tweet number  152  with id  tweet-sno-1350
# Getting image info for this url :  https://twitter.com/SweeneyABC/status/1422537706173775875/video/1
# Processing tweet number  153  with id  tweet-sno-1351
# Processing tweet number  154  with id  tweet-sno-1352
# Getting image info for this url :  https://twitter.com/Joshledore/status/981003026793054209/photo/1
# Processing tweet number  155  with id  tweet-sno-1353
# Getting image info for this url :  https://twitter.com/shaktichauhan/status/1414198205525364738/video/1
# Processing tweet number  156  with id  tweet-sno-1354
# Getting image info for this url :  https://twitter.com/PeppaPigFlorida/status/1420806360141336584/photo/1
# Processing tweet number  157  with id  tweet-sno-1355
# Processing tweet number  158  with id  tweet-sno-1356
# Getting image info for this url :  https://twitter.com/NASA/status/1420811795606933512/video/1
# Processing tweet number  159  with id  tweet-sno-1357
# Getting image info for this url :  https://twitter.com/echinoblog/status/1420069675036147713/photo/1
# Processing tweet number  160  with id  tweet-sno-1358
# Getting image info for this url :  https://twitter.com/RNCResearch/status/1420441422067552259/video/1
# Processing tweet number  161  with id  tweet-sno-1359
# Getting image info for this url :  https://twitter.com/rayleengale/status/1420501422899142658/photo/1
# Processing tweet number  162  with id  tweet-sno-1360
# Getting image info for this url :  https://twitter.com/thechrisbuskirk/status/1420035242434334720/video/1
# Processing tweet number  163  with id  tweet-sno-1361
# Getting image info for this url :  https://twitter.com/victoriamcbryde/status/1419034120290766849/photo/1
# Processing tweet number  164  with id  tweet-sno-1362
# Getting image info for this url :  https://twitter.com/i/broadcasts/1nAJELrwpkOGL
# Error: No data available for specified ID  https:
# Processing tweet number  165  with id  tweet-sno-1363
# Getting image info for this url :  https://twitter.com/katehydeny/status/1419387819953463296
# Processing tweet number  166  with id  tweet-sno-1364
# Getting image info for this url :  https://twitter.com/SPACEdotcom/status/1382311214655574021/photo/1
# Processing tweet number  167  with id  tweet-sno-1365
# Getting image info for this url :  https://twitter.com/nowthisnews/status/1417850097337978883/video/1
# Processing tweet number  168  with id  tweet-sno-1366
# Getting image info for this url :  https://twitter.com/robsheff/status/1418612339872604166/photo/1
# Processing tweet number  169  with id  tweet-sno-1367
# Processing tweet number  170  with id  tweet-sno-1368
# Getting image info for this url :  https://twitter.com/TwitterSupport/status/1417920469265788931/photo/1
# Processing tweet number  171  with id  tweet-sno-1369
# Getting image info for this url :  https://twitter.com/radfinch/status/891537917935583233
# Processing tweet number  172  with id  tweet-sno-1370
# Getting image info for this url :  https://twitter.com/adamcarolla/status/1417629839809339392/video/1
# Processing tweet number  173  with id  tweet-sno-1371
# Getting image info for this url :  https://twitter.com/McClenaghanRhys/status/1416567768938291203/video/1
# Processing tweet number  174  with id  tweet-sno-1372
# Getting image info for this url :  https://twitter.com/scottbix/status/1417512621188829184/photo/1
# Processing tweet number  175  with id  tweet-sno-1373
# Getting image info for this url :  https://twitter.com/Unexplained/status/1415391598200885249/video/1
# Processing tweet number  176  with id  tweet-sno-1374
# Getting image info for this url :  https://twitter.com/RichAzzopardi/status/1414960558726684678
# Processing tweet number  177  with id  tweet-sno-1375
# Getting image info for this url :  https://twitter.com/mccormickspices/status/1415023283020439561/video/1
# Processing tweet number  178  with id  tweet-sno-1376
# Processing tweet number  179  with id  tweet-sno-1377
# Getting image info for this url :  https://twitter.com/stphnfwlr/status/1415665393306382336/photo/1
# Processing tweet number  180  with id  tweet-sno-1378
# Getting image info for this url :  https://twitter.com/USinHolySee/status/1399720789721628676/photo/1
# Processing tweet number  181  with id  tweet-sno-1379
# Getting image info for this url :  https://twitter.com/ltthompso/status/1413200678588137486
# Getting image info for this url :  https://twitter.com/ltthompso/status/1413225868680441859/photo/1
# Processing tweet number  182  with id  tweet-sno-1380
# Getting image info for this url :  https://twitter.com/ddale8/status/1414300765900967937/photo/1
# Processing tweet number  183  with id  tweet-sno-1381
# Getting image info for this url :  https://twitter.com/nickhautman/status/1413305370672500738/photo/1
# Processing tweet number  184  with id  tweet-sno-1382
# Getting image info for this url :  https://twitter.com/LauraJaneGrace/status/1413511206141190145/photo/1
# Processing tweet number  185  with id  tweet-sno-1383
# Getting image info for this url :  https://twitter.com/MikeNeaverson/status/1341103212112318467/photo/1
# Processing tweet number  186  with id  tweet-sno-1384
# Processing tweet number  187  with id  tweet-sno-1385
# Processing tweet number  188  with id  tweet-sno-1386
# Getting image info for this url :  https://twitter.com/realbdw/status/1042344979509719041
# Processing tweet number  189  with id  tweet-sno-1387
# Processing tweet number  190  with id  tweet-sno-1388
# Processing tweet number  191  with id  tweet-sno-1389
# Getting image info for this url :  https://twitter.com/TBlountNews/status/1411757782383030272/photo/1
# Processing tweet number  192  with id  tweet-sno-1390
# Getting image info for this url :  https://twitter.com/kimleonard/status/1411727252346359809/photo/1
# Processing tweet number  193  with id  tweet-sno-1391
# Getting image info for this url :  https://twitter.com/ArtifactsHub_/status/1409715508467834887/photo/1
# Error: No data available for specified ID  1409715508467834887
# Processing tweet number  194  with id  tweet-sno-1392
# Getting image info for this url :  https://twitter.com/zsharf/status/1410256813241507841
# Processing tweet number  195  with id  tweet-sno-1393
# Getting image info for this url :  https://twitter.com/phyliciarashad/status/1410289746539130882
# Error: No data available for specified ID  1410289746539130882
# Processing tweet number  196  with id  tweet-sno-1394
# Processing tweet number  197  with id  tweet-sno-1395
# Getting image info for this url :  https://twitter.com/Brkbru/status/1361299181621702664/video/1
# Processing tweet number  198  with id  tweet-sno-1396
# Getting image info for this url :  https://twitter.com/therealjd2424/status/1409988591887863811/video/1
# Processing tweet number  199  with id  tweet-sno-1397
# Processing tweet number  200  with id  tweet-sno-1398
# Processing tweet number  201  with id  tweet-sno-1399
# Getting image info for this url :  https://twitter.com/Acyn/status/1408216358899183617/video/1
# Processing tweet number  202  with id  tweet-sno-1400
# Getting image info for this url :  https://twitter.com/acyn/status/1408216358899183617
# Processing tweet number  203  with id  tweet-sno-1401
# Getting image info for this url :  https://twitter.com/BarrySh62000603/status/1233427855960227840
# Error: No data available for specified ID  1233427855960227840
# Processing tweet number  204  with id  tweet-sno-1402
# Processing tweet number  205  with id  tweet-sno-1403
# Getting image info for this url :  https://twitter.com/ceri_weber/status/1402960827955752961/photo/1
# Processing tweet number  206  with id  tweet-sno-1404
# Getting image info for this url :  https://twitter.com/AndrewSolender/status/1405928997880533003/video/1
# Error: No data available for specified ID  1405928997880533003
# Processing tweet number  207  with id  tweet-sno-1405
# Getting image info for this url :  https://twitter.com/NikkiMcR/status/1404955461154185217/video/1
# Processing tweet number  208  with id  tweet-sno-1406
# Getting image info for this url :  https://twitter.com/kdramadaisy/status/1404615857192407044/photo/1
